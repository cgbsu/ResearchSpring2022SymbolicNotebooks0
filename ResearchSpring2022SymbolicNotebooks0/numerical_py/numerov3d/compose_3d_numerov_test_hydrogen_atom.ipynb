# %%
from numerov3d import *

# %%
from matplotlib import cm

# %%
pointCount : int = 150

# %%
grid = makeLinspaceGrid(pointCount, 1, 3)

# %%
def inifiniteSquareWell(grid : MeshGrid) -> np.ndarray: 
    return 0 * grid.x

# %%
def hydrogenAtom(grid : MeshGrid, centerX, centerY, centerZ, bottom, potential) -> np.ndarray: 
    return potential / np.sqrt(
            (grid.x - centerX) ** 2 \
            + (grid.y - centerY) ** 2 \
            + (grid.z - centerZ) ** 2 \
            + bottom ** 2 \
        )

# %%
potential = hydrogenAtom(grid, .5, .5, .5, 1e-10, 1)

# %%
figure = plt.figure(0, figsize=(9, 9))
axis = figure.add_subplot(111, projection = "3d")
axis.scatter3D(grid.x, grid.y, grid.z, c = potential, cmap = cm.seismic, s = 0.001, alpha = .6, antialiased = True)

# %%
waves = computeWaveFunction(potential)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 waves = computeWaveFunction(potential)
#
# File ~/work/numerical_py/numerov3d/numerov3d.py:102, in computeWaveFunction(potential, energyCount, eigenValueType)
#     100     assert cardinality == pointCount, "All dimensions of potential need to have the same number of elements"
#     101 mappingMatrix, _ = makeMappingMatrix(pointCount, dimensions)
# --> 102 return WaveFunctions(potential.shape, *eigsh(
#     103         makeHamiltonian(potential, pointCount, dimensions, mappingMatrix),
#     104         k = energyCount,
#     105         which = eigenValueType.value
#     106     ))
#
# File /opt/conda/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1689, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
# ...

# %%
contourCount = 200

# %%
plt.figure(figsize=(9, 9))
plt.contourf(grid.x, grid.y, waves.waveFunctions[0], contourCount)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(grid.x, grid.y, waves.probabilities[0], contourCount)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(grid.x, grid.y, waves.waveFunctions[2], contourCount)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(grid.x, grid.y, waves.probabilities[2], contourCount)
