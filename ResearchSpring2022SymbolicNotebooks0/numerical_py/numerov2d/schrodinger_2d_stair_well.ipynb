# %%
from numerov2d import *

# %%
def stairwell(
            xPositions : np.ndarray, 
            yPositions : np.ndarray, 
            unitPotentialHeight : float, 
            widthRatios : list[float], 
            heightRatios : list[float], 
            unitLength : float  = 1
        ) -> np.ndarray: 
    assert len(heightRatios) == len(widthRatios)
    potential : np.ndarray = np.zeros(xPositions.shape)
    previousLength : float = 0
    lengthRatio : float = 0
    for ii in range(len(widthRatios)): 
        lengthRatio += widthRatios[ii]
        length = lengthRatio * unitLength
        potential = np.where(
                (xPositions <= (length))
                        & (xPositions > previousLength), 
                heightRatios[ii] * unitPotentialHeight, 
                potential
            )
        previousLength = length
    return potential

# %%
pointCount : int = 150

# %%
xPositions, yPositions = positionGrid(pointCount)

# %%
potentials : np.ndarray = stairwell(xPositions, yPositions, 1, [1.0 / 3.0, 1.0 / 3.0, 1.0 / 3.0], [1.0 / 3.0, 2.0 / 3.0, 1.0])

# %%
potentials
# Out:
# array([[0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ],
#        [0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ],
#        [0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ],
#        ...,
#        [0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ],
#        [0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ],
#        [0.        , 0.33333333, 0.33333333, ..., 1.        , 1.        ,
#         1.        ]])

# %%
plt.imshow(potentials)

# %%
energies, waveFunctions = compute2dWaveFunction(pointCount, potentials)

# %%
probabilityDistributions = waveFunctions ** 2

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[0], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[1], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[2], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[3], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[4], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[0], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[1], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[2], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[3], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[4], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[9], 20)

# %%
# %matplotlib widget
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[9], 20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[4], 20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
