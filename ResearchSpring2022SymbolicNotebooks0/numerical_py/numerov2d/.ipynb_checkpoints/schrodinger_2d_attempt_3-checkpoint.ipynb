# %%
from numerov2d import *

# %%
defaultScalingFactor : float = 1

# %%
defaultReducedPlancksConstant : float = 1

# %%
defaultMass : float = 1.0

# %%
defaultLength : float = 1.0

# %%
defaultUnormalizedPositionStep : float = 1e-3

# %%
pointCount = 150

# %%
xPositions, yPositions = np.meshgrid(
        np.linspace(0, 1, pointCount, dtype=float), 
        np.linspace(0, 1, pointCount, dtype=float)
    )

# %%
def infiniteSquareWell(
            xPositions : np.ndarray, 
            yPositions : np.ndarray
        ) -> np.ndarray: 
    return 0 * xPositions

# %%
def gaussian(
            positions : np.ndarray, 
            offset : float, 
            variance : float
        ) -> np.ndarray: 
    exponent = (-1.0 / 2.0) * ((positions - offset) ** 2) / (2.0 * variance ** 2)
    scalar = 1.0 / (np.sqrt(2.0 * np.pi) * variance)
    return scalar * np.exp(exponent)

# %%
def gaussian2d(
            xPositions : np.ndarray, 
            yPositions : np.ndarray, 
            xOffset : float, 
            yOffset : float, 
            variance : float
        ) -> np.ndarray: 
    return gaussian(xPositions, xOffset, variance) * gaussian(yPositions, yOffset, variance)

# %%
potentials : np.ndarray = gaussian2d(xPositions, yPositions, .4, .5, .1)

# %%
potentials
# Out:
# array([[5.62732104e-04, 6.42846384e-04, 7.32714222e-04, ...,
#         5.64620670e-06, 4.63214426e-06, 3.79165909e-06],
#        [6.64784440e-04, 7.59427568e-04, 8.65593078e-04, ...,
#         6.67015501e-06, 5.47219077e-06, 4.47928232e-06],
#        [7.83577401e-04, 8.95132685e-04, 1.02026933e-03, ...,
#         7.86207139e-06, 6.45003819e-06, 5.27970300e-06],
#        ...,
#        [7.83577401e-04, 8.95132685e-04, 1.02026933e-03, ...,
#         7.86207139e-06, 6.45003819e-06, 5.27970300e-06],
#        [6.64784440e-04, 7.59427568e-04, 8.65593078e-04, ...,
#         6.67015501e-06, 5.47219077e-06, 4.47928232e-06],
#        [5.62732104e-04, 6.42846384e-04, 7.32714222e-04, ...,
#         5.64620670e-06, 4.63214426e-06, 3.79165909e-06]])

# %%
plt.imshow(potentials)

# %%
energies, waveFunctions = compute2dWaveFunction(pointCount, potentials)

# %%
probabilityDistributions = waveFunctions ** 2

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[0], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[1], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[2], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[3], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, waveFunctions[4], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[0], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[1], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[2], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[3], 20)

# %%
plt.figure(figsize=(9, 9))
plt.contourf(xPositions, yPositions, probabilityDistributions[4], 20)
