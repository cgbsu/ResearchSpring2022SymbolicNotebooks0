# %%
from new_attempt.stateless import *

# %%
preliminaryData = createPreliminaryData(3)

# %%
preliminaryData
# Out:
# {'transmissionReflectionGenerator': <function new_attempt.stateless.defaultTransmissionReflectionCoefficientGenerator(from_: new_attempt.stateless.RegionSymbols, to: new_attempt.stateless.RegionSymbols) -> dict>,
#  'regionSymbols': [<new_attempt.stateless.RegionSymbols at 0x7f77a43033d0>,
#   <new_attempt.stateless.RegionSymbols at 0x7f76f82a13f0>,
#   <new_attempt.stateless.RegionSymbols at 0x7f76f82a1840>,
#   <new_attempt.stateless.RegionSymbols at 0x7f76f82a1c90>,
#   <new_attempt.stateless.RegionSymbols at 0x7f76f82a20e0>],
#  'waveEquations': [Eq(V_-1*psi_-1(x) - hbarX**2*Derivative(psi_-1(x), (x, 2))/(2*m), E_{total}*psi_-1(x)),
#   Eq(V_0*psi_0(x) - hbarX**2*Derivative(psi_0(x), (x, 2))/(2*m), E_{total}*psi_0(x)),
#   Eq(V_1*psi_1(x) - hbarX**2*Derivative(psi_1(x), (x, 2))/(2*m), E_{total}*psi_1(x))],
#  'normalizations': [Eq(Integral(psi_-1(x)*conjugate(psi_-1(x)), (x, L_-2, L_-1)), N_-1),
#   Eq(Integral(psi_0(x)*conjugate(psi_0(x)), (x, L_-1, L_0)), N_0),
#   Eq(Integral(psi_1(x)*conjugate(psi_1(x)), (x, L_0, L_1)), N_1)],
#  'generalSolutions': [{'boundries': {psi_-1(L_-2): B_-1, psi_-1(L_-1): B_0},
#    'harmonicConstantEquation': Eq(k_-1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_-1)/hbarX),
#    'generalSolution': Eq(psi_-1(x), (-B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(k_-1*x) + (B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(-k_-1*x))},
#   {'boundries': {psi_0(L_-1): B_0, psi_0(L_0): B_1},
#    'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#    'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#   {'boundries': {psi_1(L_0): B_1, psi_1(L_1): B_2},
#    'harmonicConstantEquation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#    'generalSolution': Eq(psi_1(x), (B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(k_1*x) + (-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(-k_1*x))}]}

# %%
regionFunctions = generateRegionFunctions(preliminaryData)

# %%
regionFunctions
# Out:
# {'transferFunctions': {'transfers': [], 'transferFunctions': []},
#  'transmissionReflectionFunctions': [],
#  'harmonicConstantFunctions': [{'equation': Eq(k_-1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_-1)/hbarX),
#    'parameters': ['hbarX', 'm', 'E_OCBtotalCCB', 'V_N1'],
#    'function': <function _lambdifygenerated(hbarX, m, E_OCBtotalCCB, V_N1)>},
#   {'equation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#    'parameters': ['hbarX', 'V_0', 'm', 'E_OCBtotalCCB'],
#    'function': <function _lambdifygenerated(hbarX, V_0, m, E_OCBtotalCCB)>},
#   {'equation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#    'parameters': ['hbarX', 'm', 'V_1', 'E_OCBtotalCCB'],
#    'function': <function _lambdifygenerated(hbarX, m, V_1, E_OCBtotalCCB)>}],
#  'amplitudeConstantFunctions': [{'amplitudeCoefficientEquations': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f77a43033d0>,
#     'waveEquation': Eq(V_-1*psi_-1(x) - hbarX**2*Derivative(psi_-1(x), (x, 2))/(2*m), E_{total}*psi_-1(x)),
#     'normalization': Eq(Integral(psi_-1(x)*conjugate(psi_-1(x)), (x, L_-2, L_-1)), N_-1),
#     'generalSolution': {'boundries': {psi_-1(L_-2): B_-1, psi_-1(L_-1): B_0},
#      'harmonicConstantEquation': Eq(k_-1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_-1)/hbarX),
#      'generalSolution': Eq(psi_-1(x), (-B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(k_-1*x) + (B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(-k_-1*x))},
#     'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_-1(L_-2): B_-1,
#        psi_-1(L_-1): B_0},
#       'harmonicConstantEquation': Eq(k_-1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_-1)/hbarX),
#       'generalSolution': Eq(psi_-1(x), (-B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(k_-1*x) + (B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(-k_-1*x))},
#      'exponential': Eq(psi_-1(x), C_{{-1}_r}*exp(-k_-1*x) + C_{{-1}_t}*exp(k_-1*x)),
#      'amplitudes': {'transmission': -B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#       'reflection': B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#       'harmonicConstant': k_-1},
#      'expandedExponential': C_{{-1}_r}*conjugate(C_{{-1}_t}) + C_{{-1}_r}*exp(-2*k_-1*x)*conjugate(C_{{-1}_r}) + C_{{-1}_t}*exp(2*k_-1*x)*conjugate(C_{{-1}_t}) + C_{{-1}_t}*conjugate(C_{{-1}_r})},
#     'constarinedParticularSolutions': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f77a43033d0>,
#      'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_-1(L_-2): B_-1,
#         psi_-1(L_-1): B_0},
#        'harmonicConstantEquation': Eq(k_-1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_-1)/hbarX),
#        'generalSolution': Eq(psi_-1(x), (-B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(k_-1*x) + (B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))*exp(-k_-1*x))},
#       'exponential': Eq(psi_-1(x), C_{{-1}_r}*exp(-k_-1*x) + C_{{-1}_t}*exp(k_-1*x)),
#       'amplitudes': {'transmission': -B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#        'reflection': B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#        'harmonicConstant': k_-1},
#       'expandedExponential': C_{{-1}_r}*conjugate(C_{{-1}_t}) + C_{{-1}_r}*exp(-2*k_-1*x)*conjugate(C_{{-1}_r}) + C_{{-1}_t}*exp(2*k_-1*x)*conjugate(C_{{-1}_t}) + C_{{-1}_t}*conjugate(C_{{-1}_r})},
#      'intermediateSolutions': {'unconstrainedAmplitudes': {'transmission': [(-2*C_{{-1}_r}*L_-1*k_-1*exp(k_-1*(L_-1 + L_-2)) + 2*C_{{-1}_r}*L_-2*k_-1*exp(k_-1*(L_-1 + L_-2)) - sqrt(4*C_{{-1}_r}**2*L_-1**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - 8*C_{{-1}_r}**2*L_-1*L_-2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) + 4*C_{{-1}_r}**2*L_-2**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - C_{{-1}_r}**2*exp(4*L_-1*k_-1) - C_{{-1}_r}**2*exp(4*L_-2*k_-1) + 2*C_{{-1}_r}**2*exp(2*k_-1*(L_-1 + L_-2)) - 2*N_-1*k_-1*exp(2*k_-1*(L_-1 + 2*L_-2)) + 2*N_-1*k_-1*exp(2*k_-1*(2*L_-1 + L_-2))))*exp(-k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#         (-2*C_{{-1}_r}*L_-1*k_-1*exp(k_-1*(L_-1 + L_-2)) + 2*C_{{-1}_r}*L_-2*k_-1*exp(k_-1*(L_-1 + L_-2)) + sqrt(4*C_{{-1}_r}**2*L_-1**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - 8*C_{{-1}_r}**2*L_-1*L_-2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) + 4*C_{{-1}_r}**2*L_-2**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - C_{{-1}_r}**2*exp(4*L_-1*k_-1) - C_{{-1}_r}**2*exp(4*L_-2*k_-1) + 2*C_{{-1}_r}**2*exp(2*k_-1*(L_-1 + L_-2)) - 2*N_-1*k_-1*exp(2*k_-1*(L_-1 + 2*L_-2)) + 2*N_-1*k_-1*exp(2*k_-1*(2*L_-1 + L_-2))))*exp(-k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))],
#        'reflection': [(-2*C_{{-1}_t}*L_-1*k_-1*exp(k_-1*(L_-1 + L_-2)) + 2*C_{{-1}_t}*L_-2*k_-1*exp(k_-1*(L_-1 + L_-2)) - sqrt(4*C_{{-1}_t}**2*L_-1**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - 8*C_{{-1}_t}**2*L_-1*L_-2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) + 4*C_{{-1}_t}**2*L_-2**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - C_{{-1}_t}**2*exp(4*L_-1*k_-1) - C_{{-1}_t}**2*exp(4*L_-2*k_-1) + 2*C_{{-1}_t}**2*exp(2*k_-1*(L_-1 + L_-2)) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1)))*exp(k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#         (-2*C_{{-1}_t}*L_-1*k_-1*exp(k_-1*(L_-1 + L_-2)) + 2*C_{{-1}_t}*L_-2*k_-1*exp(k_-1*(L_-1 + L_-2)) + sqrt(4*C_{{-1}_t}**2*L_-1**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - 8*C_{{-1}_t}**2*L_-1*L_-2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) + 4*C_{{-1}_t}**2*L_-2**2*k_-1**2*exp(2*k_-1*(L_-1 + L_-2)) - C_{{-1}_t}**2*exp(4*L_-1*k_-1) - C_{{-1}_t}**2*exp(4*L_-2*k_-1) + 2*C_{{-1}_t}**2*exp(2*k_-1*(L_-1 + L_-2)) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1)))*exp(k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))]},
#       'intermediateSolutions': {'transmission': Eq((-B_-1*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) + B_0*exp(L_-1*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))**2, (C_{{-1}_r}**2*exp(2*L_-1*k_-1) - C_{{-1}_r}**2*exp(2*L_-2*k_-1) - 2*N_-1*k_-1*exp(2*k_-1*(L_-1 + L_-2)))*exp(-2*k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))),
#        'reflection': Eq((B_-1*exp(2*L_-1*k_-1)*exp(L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)) - B_0*exp(L_-1*k_-1)*exp(2*L_-2*k_-1)/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))**2, (C_{{-1}_t}**2*exp(2*L_-1*k_-1) - C_{{-1}_t}**2*exp(2*L_-2*k_-1) - 2*N_-1*k_-1)*exp(2*k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)))}},
#      'constrainedParticularSolution': {'amplitudeConstrainedSolutions': {'transmission': [-sqrt(B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#         sqrt(B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))],
#        'reflection': [-sqrt(B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1))*exp(k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1)),
#         sqrt(B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1))*exp(k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))]},
#       'amplitudeConstrainedSolution': {'transmission': Eq(C_{{-1}_t}**2, (-B_-1**2*exp(2*L_-1*k_-1) + 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) - B_0**2*exp(2*L_-2*k_-1) - 2*N_-1*k_-1*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-2*k_-1))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))**2),
#        'reflection': Eq(C_{{-1}_r}**2, (-B_-1**2*exp(2*L_-2*k_-1) + 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) - B_0**2*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-2*k_-1))*exp(2*k_-1*(L_-1 + L_-2))/(exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1))**2)}}},
#     'extrapolatedComponentsOfConstants': {'C_OCBOCBN1CCB_tCCB': {'components': [{'C_OCBOCBN1CCB_tCCB0radicand': {'component': B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCBN1CCB_tCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCBN1CCB_tCCB0inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCBN1CCB_tCCB0scalar': {'component': -1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCBN1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#           'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#          'C_OCBOCBN1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']},
#          'C_OCBOCBN1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction',
#          'C_OCBOCBN1CCB_tCCB0offsetFunction',
#          'C_OCBOCBN1CCB_tCCB0radicandFunction',
#          'C_OCBOCBN1CCB_tCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction, C_OCBOCBN1CCB_tCCB0offsetFunction, C_OCBOCBN1CCB_tCCB0radicandFunction, C_OCBOCBN1CCB_tCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#            'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#           'C_OCBOCBN1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']},
#           'C_OCBOCBN1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_tCCB0radicandFunction',
#           'offset': 'C_OCBOCBN1CCB_tCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCBN1CCB_tCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}},
#        {'C_OCBOCBN1CCB_tCCB1radicand': {'component': B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCBN1CCB_tCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCBN1CCB_tCCB1inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCBN1CCB_tCCB1scalar': {'component': 1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCBN1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#           'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#          'C_OCBOCBN1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']},
#          'C_OCBOCBN1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction',
#          'C_OCBOCBN1CCB_tCCB1offsetFunction',
#          'C_OCBOCBN1CCB_tCCB1radicandFunction',
#          'C_OCBOCBN1CCB_tCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction, C_OCBOCBN1CCB_tCCB1offsetFunction, C_OCBOCBN1CCB_tCCB1radicandFunction, C_OCBOCBN1CCB_tCCB1scalarFunction)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#            'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#           'C_OCBOCBN1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']},
#           'C_OCBOCBN1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_tCCB1radicandFunction',
#           'offset': 'C_OCBOCBN1CCB_tCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCBN1CCB_tCCB1scalarFunction'},
#          'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}}]},
#      'C_OCBOCBN1CCB_rCCB': {'components': [{'C_OCBOCBN1CCB_rCCB0radicand': {'component': B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCBN1CCB_rCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCBN1CCB_rCCB0inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCBN1CCB_rCCB0scalar': {'component': -exp(k_-1*(L_-1 + L_-2)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCBN1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#           'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#          'C_OCBOCBN1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']},
#          'C_OCBOCBN1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#         'generalFunctionParameters': ['C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCBN1CCB_rCCB0offsetFunction',
#          'C_OCBOCBN1CCB_rCCB0radicandFunction',
#          'C_OCBOCBN1CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction, C_OCBOCBN1CCB_rCCB0offsetFunction, C_OCBOCBN1CCB_rCCB0radicandFunction, C_OCBOCBN1CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#            'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#           'C_OCBOCBN1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']},
#           'C_OCBOCBN1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCBN1CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCBN1CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}},
#        {'C_OCBOCBN1CCB_rCCB1radicand': {'component': B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCBN1CCB_rCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCBN1CCB_rCCB1inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCBN1CCB_rCCB1scalar': {'component': exp(k_-1*(L_-1 + L_-2)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCBN1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#           'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#          'C_OCBOCBN1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']},
#          'C_OCBOCBN1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#           'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#         'generalFunctionParameters': ['C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction',
#          'C_OCBOCBN1CCB_rCCB1offsetFunction',
#          'C_OCBOCBN1CCB_rCCB1radicandFunction',
#          'C_OCBOCBN1CCB_rCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction, C_OCBOCBN1CCB_rCCB1offsetFunction, C_OCBOCBN1CCB_rCCB1radicandFunction, C_OCBOCBN1CCB_rCCB1scalarFunction)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#            'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#           'C_OCBOCBN1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']},
#           'C_OCBOCBN1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#            'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_rCCB1radicandFunction',
#           'offset': 'C_OCBOCBN1CCB_rCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCBN1CCB_rCCB1scalarFunction'},
#          'allParameters': {'B_0',
#           'B_N1',
#           'L_N1',
#           'L_N2',
#           'N_N1',
#           'k_N1'}}}]}}},
#    'constantAmplitudeCalculations': {'C_OCBOCBN1CCB_tCCB': [{'C_OCBOCBN1CCB_tCCB0radicand': {'component': B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCBN1CCB_tCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCBN1CCB_tCCB0inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCBN1CCB_tCCB0scalar': {'component': -1,
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCBN1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#        'C_OCBOCBN1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']},
#        'C_OCBOCBN1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction',
#        'C_OCBOCBN1CCB_tCCB0offsetFunction',
#        'C_OCBOCBN1CCB_tCCB0radicandFunction',
#        'C_OCBOCBN1CCB_tCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction, C_OCBOCBN1CCB_tCCB0offsetFunction, C_OCBOCBN1CCB_tCCB0radicandFunction, C_OCBOCBN1CCB_tCCB0scalarFunction)>,
#       'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#          'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#         'C_OCBOCBN1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']},
#         'C_OCBOCBN1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_tCCB0radicandFunction',
#         'offset': 'C_OCBOCBN1CCB_tCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCBN1CCB_tCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCBN1CCB_tCCB0scalarFunction'},
#        'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}},
#      {'C_OCBOCBN1CCB_tCCB1radicand': {'component': B_-1**2*exp(2*L_-1*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-2*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCBN1CCB_tCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCBN1CCB_tCCB1inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCBN1CCB_tCCB1scalar': {'component': 1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCBN1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#        'C_OCBOCBN1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']},
#        'C_OCBOCBN1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction',
#        'C_OCBOCBN1CCB_tCCB1offsetFunction',
#        'C_OCBOCBN1CCB_tCCB1radicandFunction',
#        'C_OCBOCBN1CCB_tCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction, C_OCBOCBN1CCB_tCCB1offsetFunction, C_OCBOCBN1CCB_tCCB1radicandFunction, C_OCBOCBN1CCB_tCCB1scalarFunction)>,
#       'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#          'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#         'C_OCBOCBN1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']},
#         'C_OCBOCBN1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_tCCB1radicandFunction',
#         'offset': 'C_OCBOCBN1CCB_tCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCBN1CCB_tCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCBN1CCB_tCCB1scalarFunction'},
#        'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}}],
#     'C_OCBOCBN1CCB_rCCB': [{'C_OCBOCBN1CCB_rCCB0radicand': {'component': B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCBN1CCB_rCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCBN1CCB_rCCB0inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCBN1CCB_rCCB0scalar': {'component': -exp(k_-1*(L_-1 + L_-2)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCBN1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#        'C_OCBOCBN1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']},
#        'C_OCBOCBN1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#       'generalFunctionParameters': ['C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction',
#        'C_OCBOCBN1CCB_rCCB0offsetFunction',
#        'C_OCBOCBN1CCB_rCCB0radicandFunction',
#        'C_OCBOCBN1CCB_rCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction, C_OCBOCBN1CCB_rCCB0offsetFunction, C_OCBOCBN1CCB_rCCB0radicandFunction, C_OCBOCBN1CCB_rCCB0scalarFunction)>,
#       'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#          'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#         'C_OCBOCBN1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']},
#         'C_OCBOCBN1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_rCCB0radicandFunction',
#         'offset': 'C_OCBOCBN1CCB_rCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCBN1CCB_rCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCBN1CCB_rCCB0scalarFunction'},
#        'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}},
#      {'C_OCBOCBN1CCB_rCCB1radicand': {'component': B_-1**2*exp(2*L_-2*k_-1) - 2*B_-1*B_0*exp(k_-1*(L_-1 + L_-2)) + B_0**2*exp(2*L_-1*k_-1) + 2*N_-1*k_-1*exp(2*L_-1*k_-1) - 2*N_-1*k_-1*exp(2*L_-2*k_-1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCBN1CCB_rCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCBN1CCB_rCCB1inverseCoefficent': {'component': exp(2*L_-1*k_-1) - exp(2*L_-2*k_-1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCBN1CCB_rCCB1scalar': {'component': exp(k_-1*(L_-1 + L_-2)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCBN1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#         'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#        'C_OCBOCBN1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']},
#        'C_OCBOCBN1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#         'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#       'generalFunctionParameters': ['C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction',
#        'C_OCBOCBN1CCB_rCCB1offsetFunction',
#        'C_OCBOCBN1CCB_rCCB1radicandFunction',
#        'C_OCBOCBN1CCB_rCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction, C_OCBOCBN1CCB_rCCB1offsetFunction, C_OCBOCBN1CCB_rCCB1radicandFunction, C_OCBOCBN1CCB_rCCB1scalarFunction)>,
#       'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCBN1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_N1, L_N1, L_N2, N_N1, k_N1)>,
#          'parameters': ['B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1']},
#         'C_OCBOCBN1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']},
#         'C_OCBOCBN1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_N1, L_N2, k_N1)>,
#          'parameters': ['L_N1', 'L_N2', 'k_N1']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCBN1CCB_rCCB1radicandFunction',
#         'offset': 'C_OCBOCBN1CCB_rCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCBN1CCB_rCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCBN1CCB_rCCB1scalarFunction'},
#        'allParameters': {'B_0', 'B_N1', 'L_N1', 'L_N2', 'N_N1', 'k_N1'}}}]}},
#   {'amplitudeCoefficientEquations': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f76f82a13f0>,
#     'waveEquation': Eq(V_0*psi_0(x) - hbarX**2*Derivative(psi_0(x), (x, 2))/(2*m), E_{total}*psi_0(x)),
#     'normalization': Eq(Integral(psi_0(x)*conjugate(psi_0(x)), (x, L_-1, L_0)), N_0),
#     'generalSolution': {'boundries': {psi_0(L_-1): B_0, psi_0(L_0): B_1},
#      'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#      'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#     'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_0(L_-1): B_0,
#        psi_0(L_0): B_1},
#       'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#       'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#      'exponential': Eq(psi_0(x), C_{{0}_r}*exp(-k_0*x) + C_{{0}_t}*exp(k_0*x)),
#      'amplitudes': {'transmission': B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#       'reflection': -B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#       'harmonicConstant': k_0},
#      'expandedExponential': C_{{0}_r}*conjugate(C_{{0}_t}) + C_{{0}_r}*exp(-2*k_0*x)*conjugate(C_{{0}_r}) + C_{{0}_t}*exp(2*k_0*x)*conjugate(C_{{0}_t}) + C_{{0}_t}*conjugate(C_{{0}_r})},
#     'constarinedParticularSolutions': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f76f82a13f0>,
#      'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_0(L_-1): B_0,
#         psi_0(L_0): B_1},
#        'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#        'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#       'exponential': Eq(psi_0(x), C_{{0}_r}*exp(-k_0*x) + C_{{0}_t}*exp(k_0*x)),
#       'amplitudes': {'transmission': B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#        'reflection': -B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#        'harmonicConstant': k_0},
#       'expandedExponential': C_{{0}_r}*conjugate(C_{{0}_t}) + C_{{0}_r}*exp(-2*k_0*x)*conjugate(C_{{0}_r}) + C_{{0}_t}*exp(2*k_0*x)*conjugate(C_{{0}_t}) + C_{{0}_t}*conjugate(C_{{0}_r})},
#      'intermediateSolutions': {'unconstrainedAmplitudes': {'transmission': [(-2*C_{{0}_r}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_r}*L_0*k_0*exp(k_0*(L_-1 + L_0)) - sqrt(4*C_{{0}_r}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_r}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_r}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_r}**2*exp(4*L_-1*k_0) - C_{{0}_r}**2*exp(4*L_0*k_0) + 2*C_{{0}_r}**2*exp(2*k_0*(L_-1 + L_0)) + 2*N_0*k_0*exp(2*k_0*(L_-1 + 2*L_0)) - 2*N_0*k_0*exp(2*k_0*(2*L_-1 + L_0))))*exp(-k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         (-2*C_{{0}_r}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_r}*L_0*k_0*exp(k_0*(L_-1 + L_0)) + sqrt(4*C_{{0}_r}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_r}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_r}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_r}**2*exp(4*L_-1*k_0) - C_{{0}_r}**2*exp(4*L_0*k_0) + 2*C_{{0}_r}**2*exp(2*k_0*(L_-1 + L_0)) + 2*N_0*k_0*exp(2*k_0*(L_-1 + 2*L_0)) - 2*N_0*k_0*exp(2*k_0*(2*L_-1 + L_0))))*exp(-k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))],
#        'reflection': [(-2*C_{{0}_t}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_t}*L_0*k_0*exp(k_0*(L_-1 + L_0)) - sqrt(4*C_{{0}_t}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_t}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_t}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_t}**2*exp(4*L_-1*k_0) - C_{{0}_t}**2*exp(4*L_0*k_0) + 2*C_{{0}_t}**2*exp(2*k_0*(L_-1 + L_0)) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0)))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         (-2*C_{{0}_t}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_t}*L_0*k_0*exp(k_0*(L_-1 + L_0)) + sqrt(4*C_{{0}_t}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_t}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_t}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_t}**2*exp(4*L_-1*k_0) - C_{{0}_t}**2*exp(4*L_0*k_0) + 2*C_{{0}_t}**2*exp(2*k_0*(L_-1 + L_0)) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0)))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))]},
#       'intermediateSolutions': {'transmission': Eq((B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))**2, (C_{{0}_r}**2*exp(2*L_-1*k_0) - C_{{0}_r}**2*exp(2*L_0*k_0) + 2*N_0*k_0*exp(2*k_0*(L_-1 + L_0)))*exp(-2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))),
#        'reflection': Eq((-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))**2, (C_{{0}_t}**2*exp(2*L_-1*k_0) - C_{{0}_t}**2*exp(2*L_0*k_0) + 2*N_0*k_0)*exp(2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))}},
#      'constrainedParticularSolution': {'amplitudeConstrainedSolutions': {'transmission': [-sqrt(B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         sqrt(B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))],
#        'reflection': [-sqrt(B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         sqrt(B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))]},
#       'amplitudeConstrainedSolution': {'transmission': Eq(C_{{0}_t}**2, (-B_0**2*exp(2*L_0*k_0) + 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) - B_1**2*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))**2),
#        'reflection': Eq(C_{{0}_r}**2, (-B_0**2*exp(2*L_-1*k_0) + 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) - B_1**2*exp(2*L_0*k_0) + 2*N_0*k_0*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_0*k_0))*exp(2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))**2)}}},
#     'extrapolatedComponentsOfConstants': {'C_OCBOCB0CCB_tCCB': {'components': [{'C_OCBOCB0CCB_tCCB0radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_tCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_tCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_tCCB0scalar': {'component': -1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#          'C_OCBOCB0CCB_tCCB0offsetFunction',
#          'C_OCBOCB0CCB_tCCB0radicandFunction',
#          'C_OCBOCB0CCB_tCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB0inverseCoefficentFunction, C_OCBOCB0CCB_tCCB0offsetFunction, C_OCBOCB0CCB_tCCB0radicandFunction, C_OCBOCB0CCB_tCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB0radicandFunction',
#           'offset': 'C_OCBOCB0CCB_tCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_tCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
#        {'C_OCBOCB0CCB_tCCB1radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_tCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_tCCB1inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_tCCB1scalar': {'component': 1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#          'C_OCBOCB0CCB_tCCB1offsetFunction',
#          'C_OCBOCB0CCB_tCCB1radicandFunction',
#          'C_OCBOCB0CCB_tCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB1inverseCoefficentFunction, C_OCBOCB0CCB_tCCB1offsetFunction, C_OCBOCB0CCB_tCCB1radicandFunction, C_OCBOCB0CCB_tCCB1scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB1radicandFunction',
#           'offset': 'C_OCBOCB0CCB_tCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_tCCB1scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}}]},
#      'C_OCBOCB0CCB_rCCB': {'components': [{'C_OCBOCB0CCB_rCCB0radicand': {'component': B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_rCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_rCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_rCCB0scalar': {'component': -exp(k_0*(L_-1 + L_0)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCB0CCB_rCCB0offsetFunction',
#          'C_OCBOCB0CCB_rCCB0radicandFunction',
#          'C_OCBOCB0CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_rCCB0inverseCoefficentFunction, C_OCBOCB0CCB_rCCB0offsetFunction, C_OCBOCB0CCB_rCCB0radicandFunction, C_OCBOCB0CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCB0CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
# ...
#          'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCB1CCB_rCCB0offsetFunction',
#          'C_OCBOCB1CCB_rCCB0radicandFunction',
#          'C_OCBOCB1CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_rCCB0inverseCoefficentFunction, C_OCBOCB1CCB_rCCB0offsetFunction, C_OCBOCB1CCB_rCCB0radicandFunction, C_OCBOCB1CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#            'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCB1CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB1CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}},
#        {'C_OCBOCB1CCB_rCCB1radicand': {'component': B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB1CCB_rCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB1CCB_rCCB1inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB1CCB_rCCB1scalar': {'component': exp(k_1*(L_0 + L_1)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#           'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB1inverseCoefficentFunction',
#          'C_OCBOCB1CCB_rCCB1offsetFunction',
#          'C_OCBOCB1CCB_rCCB1radicandFunction',
#          'C_OCBOCB1CCB_rCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_rCCB1inverseCoefficentFunction, C_OCBOCB1CCB_rCCB1offsetFunction, C_OCBOCB1CCB_rCCB1radicandFunction, C_OCBOCB1CCB_rCCB1scalarFunction)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#            'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_rCCB1radicandFunction',
#           'offset': 'C_OCBOCB1CCB_rCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB1CCB_rCCB1scalarFunction'},
#          'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}}]}}},
#    'constantAmplitudeCalculations': {'C_OCBOCB1CCB_tCCB': [{'C_OCBOCB1CCB_tCCB0radicand': {'component': B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB1CCB_tCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB1CCB_tCCB0inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB1CCB_tCCB0scalar': {'component': -1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#        'C_OCBOCB1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']},
#        'C_OCBOCB1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB1CCB_tCCB0inverseCoefficentFunction',
#        'C_OCBOCB1CCB_tCCB0offsetFunction',
#        'C_OCBOCB1CCB_tCCB0radicandFunction',
#        'C_OCBOCB1CCB_tCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_tCCB0inverseCoefficentFunction, C_OCBOCB1CCB_tCCB0offsetFunction, C_OCBOCB1CCB_tCCB0radicandFunction, C_OCBOCB1CCB_tCCB0scalarFunction)>,
#       'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#          'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#         'C_OCBOCB1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']},
#         'C_OCBOCB1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_tCCB0radicandFunction',
#         'offset': 'C_OCBOCB1CCB_tCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB1CCB_tCCB0scalarFunction'},
#        'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}},
#      {'C_OCBOCB1CCB_tCCB1radicand': {'component': B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB1CCB_tCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB1CCB_tCCB1inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB1CCB_tCCB1scalar': {'component': 1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#        'C_OCBOCB1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']},
#        'C_OCBOCB1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB1CCB_tCCB1inverseCoefficentFunction',
#        'C_OCBOCB1CCB_tCCB1offsetFunction',
#        'C_OCBOCB1CCB_tCCB1radicandFunction',
#        'C_OCBOCB1CCB_tCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_tCCB1inverseCoefficentFunction, C_OCBOCB1CCB_tCCB1offsetFunction, C_OCBOCB1CCB_tCCB1radicandFunction, C_OCBOCB1CCB_tCCB1scalarFunction)>,
#       'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#          'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#         'C_OCBOCB1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']},
#         'C_OCBOCB1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_tCCB1radicandFunction',
#         'offset': 'C_OCBOCB1CCB_tCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB1CCB_tCCB1scalarFunction'},
#        'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}}],
#     'C_OCBOCB1CCB_rCCB': [{'C_OCBOCB1CCB_rCCB0radicand': {'component': B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB1CCB_rCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB1CCB_rCCB0inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB1CCB_rCCB0scalar': {'component': -exp(k_1*(L_0 + L_1)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#        'C_OCBOCB1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']},
#        'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']}},
#       'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#        'C_OCBOCB1CCB_rCCB0offsetFunction',
#        'C_OCBOCB1CCB_rCCB0radicandFunction',
#        'C_OCBOCB1CCB_rCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_rCCB0inverseCoefficentFunction, C_OCBOCB1CCB_rCCB0offsetFunction, C_OCBOCB1CCB_rCCB0radicandFunction, C_OCBOCB1CCB_rCCB0scalarFunction)>,
#       'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#          'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#         'C_OCBOCB1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']},
#         'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_rCCB0radicandFunction',
#         'offset': 'C_OCBOCB1CCB_rCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB1CCB_rCCB0scalarFunction'},
#        'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}},
#      {'C_OCBOCB1CCB_rCCB1radicand': {'component': B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB1CCB_rCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB1CCB_rCCB1inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB1CCB_rCCB1scalar': {'component': exp(k_1*(L_0 + L_1)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#        'C_OCBOCB1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']},
#        'C_OCBOCB1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#         'parameters': ['L_0', 'L_1', 'k_1']}},
#       'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB1inverseCoefficentFunction',
#        'C_OCBOCB1CCB_rCCB1offsetFunction',
#        'C_OCBOCB1CCB_rCCB1radicandFunction',
#        'C_OCBOCB1CCB_rCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_rCCB1inverseCoefficentFunction, C_OCBOCB1CCB_rCCB1offsetFunction, C_OCBOCB1CCB_rCCB1radicandFunction, C_OCBOCB1CCB_rCCB1scalarFunction)>,
#       'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#          'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#         'C_OCBOCB1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']},
#         'C_OCBOCB1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#          'parameters': ['L_0', 'L_1', 'k_1']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_rCCB1radicandFunction',
#         'offset': 'C_OCBOCB1CCB_rCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB1CCB_rCCB1scalarFunction'},
#        'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}}]}}]}
