# %%
from new_attempt.stateless import *

# %%
preliminaryData = createPreliminaryData(3)

# %%
preliminaryData
# Out:
# {'transmissionReflectionGenerator': <function new_attempt.stateless.defaultTransmissionReflectionCoefficientGenerator(from_: new_attempt.stateless.RegionSymbols, to: new_attempt.stateless.RegionSymbols) -> dict>,
#  'regionSymbols': [<new_attempt.stateless.RegionSymbols at 0x7f3490719090>,
#   <new_attempt.stateless.RegionSymbols at 0x7f33eb0e15a0>,
#   <new_attempt.stateless.RegionSymbols at 0x7f33eb0e19f0>,
#   <new_attempt.stateless.RegionSymbols at 0x7f33eb0e1e40>,
#   <new_attempt.stateless.RegionSymbols at 0x7f33eb0e2290>],
#  'waveEquations': [Eq(V_0*psi_0(x) - hbarX**2*Derivative(psi_0(x), (x, 2))/(2*m), E_{total}*psi_0(x)),
#   Eq(V_1*psi_1(x) - hbarX**2*Derivative(psi_1(x), (x, 2))/(2*m), E_{total}*psi_1(x)),
#   Eq(V_2*psi_2(x) - hbarX**2*Derivative(psi_2(x), (x, 2))/(2*m), E_{total}*psi_2(x))],
#  'normalizations': [Eq(Integral(psi_0(x)*conjugate(psi_0(x)), (x, L_-1, L_0)), N_0),
#   Eq(Integral(psi_1(x)*conjugate(psi_1(x)), (x, L_0, L_1)), N_1),
#   Eq(Integral(psi_2(x)*conjugate(psi_2(x)), (x, L_1, L_2)), N_2)],
#  'generalSolutions': [{'boundries': {psi_0(L_-1): B_0, psi_0(L_0): B_1},
#    'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#    'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#   {'boundries': {psi_1(L_0): B_1, psi_1(L_1): B_2},
#    'harmonicConstantEquation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#    'generalSolution': Eq(psi_1(x), (B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(k_1*x) + (-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(-k_1*x))},
#   {'boundries': {psi_2(L_1): B_2, psi_2(L_2): B_3},
#    'harmonicConstantEquation': Eq(k_2, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_2)/hbarX),
#    'generalSolution': Eq(psi_2(x), (B_2*exp(L_1*k_2)/(exp(2*L_1*k_2) - exp(2*L_2*k_2)) - B_3*exp(L_2*k_2)/(exp(2*L_1*k_2) - exp(2*L_2*k_2)))*exp(k_2*x) + (-B_2*exp(L_1*k_2)*exp(2*L_2*k_2)/(exp(2*L_1*k_2) - exp(2*L_2*k_2)) + B_3*exp(2*L_1*k_2)*exp(L_2*k_2)/(exp(2*L_1*k_2) - exp(2*L_2*k_2)))*exp(-k_2*x))}]}

# %%
regionFunctions = generateRegionFunctions(preliminaryData)

# %%
regionFunctions
# Out:
# {'transferFunctions': {'transfers': [], 'transferFunctions': []},
#  'transmissionReflectionFunctions': [],
#  'harmonicConstantFunctions': [{'equation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#    'parameters': ['E_OCBtotalCCB', 'V_0', 'hbarX', 'm'],
#    'function': <function _lambdifygenerated(E_OCBtotalCCB, V_0, hbarX, m)>},
#   {'equation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#    'parameters': ['V_1', 'E_OCBtotalCCB', 'hbarX', 'm'],
#    'function': <function _lambdifygenerated(V_1, E_OCBtotalCCB, hbarX, m)>},
#   {'equation': Eq(k_2, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_2)/hbarX),
#    'parameters': ['E_OCBtotalCCB', 'V_2', 'hbarX', 'm'],
#    'function': <function _lambdifygenerated(E_OCBtotalCCB, V_2, hbarX, m)>}],
#  'amplitudeConstantFunctions': [{'amplitudeCoefficientEquations': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f33eb0e15a0>,
#     'waveEquation': Eq(V_0*psi_0(x) - hbarX**2*Derivative(psi_0(x), (x, 2))/(2*m), E_{total}*psi_0(x)),
#     'normalization': Eq(Integral(psi_0(x)*conjugate(psi_0(x)), (x, L_-1, L_0)), N_0),
#     'generalSolution': {'boundries': {psi_0(L_-1): B_0, psi_0(L_0): B_1},
#      'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#      'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#     'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_0(L_-1): B_0,
#        psi_0(L_0): B_1},
#       'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#       'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#      'exponential': Eq(psi_0(x), C_{{0}_r}*exp(-k_0*x) + C_{{0}_t}*exp(k_0*x)),
#      'amplitudes': {'transmission': B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#       'reflection': -B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#       'harmonicConstant': k_0},
#      'expandedExponential': C_{{0}_r}*conjugate(C_{{0}_t}) + C_{{0}_r}*exp(-2*k_0*x)*conjugate(C_{{0}_r}) + C_{{0}_t}*exp(2*k_0*x)*conjugate(C_{{0}_t}) + C_{{0}_t}*conjugate(C_{{0}_r})},
#     'constarinedParticularSolutions': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f33eb0e15a0>,
#      'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_0(L_-1): B_0,
#         psi_0(L_0): B_1},
#        'harmonicConstantEquation': Eq(k_0, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_0)/hbarX),
#        'generalSolution': Eq(psi_0(x), (B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(k_0*x) + (-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))*exp(-k_0*x))},
#       'exponential': Eq(psi_0(x), C_{{0}_r}*exp(-k_0*x) + C_{{0}_t}*exp(k_0*x)),
#       'amplitudes': {'transmission': B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#        'reflection': -B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#        'harmonicConstant': k_0},
#       'expandedExponential': C_{{0}_r}*conjugate(C_{{0}_t}) + C_{{0}_r}*exp(-2*k_0*x)*conjugate(C_{{0}_r}) + C_{{0}_t}*exp(2*k_0*x)*conjugate(C_{{0}_t}) + C_{{0}_t}*conjugate(C_{{0}_r})},
#      'intermediateSolutions': {'unconstrainedAmplitudes': {'transmission': [(-2*C_{{0}_r}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_r}*L_0*k_0*exp(k_0*(L_-1 + L_0)) - sqrt(4*C_{{0}_r}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_r}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_r}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_r}**2*exp(4*L_-1*k_0) - C_{{0}_r}**2*exp(4*L_0*k_0) + 2*C_{{0}_r}**2*exp(2*k_0*(L_-1 + L_0)) + 2*N_0*k_0*exp(2*k_0*(L_-1 + 2*L_0)) - 2*N_0*k_0*exp(2*k_0*(2*L_-1 + L_0))))*exp(-k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         (-2*C_{{0}_r}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_r}*L_0*k_0*exp(k_0*(L_-1 + L_0)) + sqrt(4*C_{{0}_r}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_r}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_r}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_r}**2*exp(4*L_-1*k_0) - C_{{0}_r}**2*exp(4*L_0*k_0) + 2*C_{{0}_r}**2*exp(2*k_0*(L_-1 + L_0)) + 2*N_0*k_0*exp(2*k_0*(L_-1 + 2*L_0)) - 2*N_0*k_0*exp(2*k_0*(2*L_-1 + L_0))))*exp(-k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))],
#        'reflection': [(-2*C_{{0}_t}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_t}*L_0*k_0*exp(k_0*(L_-1 + L_0)) - sqrt(4*C_{{0}_t}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_t}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_t}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_t}**2*exp(4*L_-1*k_0) - C_{{0}_t}**2*exp(4*L_0*k_0) + 2*C_{{0}_t}**2*exp(2*k_0*(L_-1 + L_0)) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0)))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         (-2*C_{{0}_t}*L_-1*k_0*exp(k_0*(L_-1 + L_0)) + 2*C_{{0}_t}*L_0*k_0*exp(k_0*(L_-1 + L_0)) + sqrt(4*C_{{0}_t}**2*L_-1**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - 8*C_{{0}_t}**2*L_-1*L_0*k_0**2*exp(2*k_0*(L_-1 + L_0)) + 4*C_{{0}_t}**2*L_0**2*k_0**2*exp(2*k_0*(L_-1 + L_0)) - C_{{0}_t}**2*exp(4*L_-1*k_0) - C_{{0}_t}**2*exp(4*L_0*k_0) + 2*C_{{0}_t}**2*exp(2*k_0*(L_-1 + L_0)) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0)))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))]},
#       'intermediateSolutions': {'transmission': Eq((B_0*exp(L_-1*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) - B_1*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))**2, (C_{{0}_r}**2*exp(2*L_-1*k_0) - C_{{0}_r}**2*exp(2*L_0*k_0) + 2*N_0*k_0*exp(2*k_0*(L_-1 + L_0)))*exp(-2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))),
#        'reflection': Eq((-B_0*exp(L_-1*k_0)*exp(2*L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)) + B_1*exp(2*L_-1*k_0)*exp(L_0*k_0)/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))**2, (C_{{0}_t}**2*exp(2*L_-1*k_0) - C_{{0}_t}**2*exp(2*L_0*k_0) + 2*N_0*k_0)*exp(2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)))}},
#      'constrainedParticularSolution': {'amplitudeConstrainedSolutions': {'transmission': [-sqrt(B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         sqrt(B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))],
#        'reflection': [-sqrt(B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0)),
#         sqrt(B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0))*exp(k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))]},
#       'amplitudeConstrainedSolution': {'transmission': Eq(C_{{0}_t}**2, (-B_0**2*exp(2*L_0*k_0) + 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) - B_1**2*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_0*k_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))**2),
#        'reflection': Eq(C_{{0}_r}**2, (-B_0**2*exp(2*L_-1*k_0) + 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) - B_1**2*exp(2*L_0*k_0) + 2*N_0*k_0*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_0*k_0))*exp(2*k_0*(L_-1 + L_0))/(exp(2*L_-1*k_0) - exp(2*L_0*k_0))**2)}}},
#     'extrapolatedComponentsOfConstants': {'C_OCBOCB0CCB_tCCB': {'components': [{'C_OCBOCB0CCB_tCCB0radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_tCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_tCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_tCCB0scalar': {'component': -1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#          'C_OCBOCB0CCB_tCCB0offsetFunction',
#          'C_OCBOCB0CCB_tCCB0radicandFunction',
#          'C_OCBOCB0CCB_tCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB0inverseCoefficentFunction, C_OCBOCB0CCB_tCCB0offsetFunction, C_OCBOCB0CCB_tCCB0radicandFunction, C_OCBOCB0CCB_tCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB0radicandFunction',
#           'offset': 'C_OCBOCB0CCB_tCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_tCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
#        {'C_OCBOCB0CCB_tCCB1radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_tCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_tCCB1inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_tCCB1scalar': {'component': 1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#          'C_OCBOCB0CCB_tCCB1offsetFunction',
#          'C_OCBOCB0CCB_tCCB1radicandFunction',
#          'C_OCBOCB0CCB_tCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB1inverseCoefficentFunction, C_OCBOCB0CCB_tCCB1offsetFunction, C_OCBOCB0CCB_tCCB1radicandFunction, C_OCBOCB0CCB_tCCB1scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB1radicandFunction',
#           'offset': 'C_OCBOCB0CCB_tCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_tCCB1scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}}]},
#      'C_OCBOCB0CCB_rCCB': {'components': [{'C_OCBOCB0CCB_rCCB0radicand': {'component': B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_rCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_rCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_rCCB0scalar': {'component': -exp(k_0*(L_-1 + L_0)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCB0CCB_rCCB0offsetFunction',
#          'C_OCBOCB0CCB_rCCB0radicandFunction',
#          'C_OCBOCB0CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_rCCB0inverseCoefficentFunction, C_OCBOCB0CCB_rCCB0offsetFunction, C_OCBOCB0CCB_rCCB0radicandFunction, C_OCBOCB0CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCB0CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
#        {'C_OCBOCB0CCB_rCCB1radicand': {'component': B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB0CCB_rCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB0CCB_rCCB1inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB0CCB_rCCB1scalar': {'component': exp(k_0*(L_-1 + L_0)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB0CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#           'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#          'C_OCBOCB0CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']},
#          'C_OCBOCB0CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#           'parameters': ['L_0', 'L_N1', 'k_0']}},
#         'generalFunctionParameters': ['C_OCBOCB0CCB_rCCB1inverseCoefficentFunction',
#          'C_OCBOCB0CCB_rCCB1offsetFunction',
#          'C_OCBOCB0CCB_rCCB1radicandFunction',
#          'C_OCBOCB0CCB_rCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_rCCB1inverseCoefficentFunction, C_OCBOCB0CCB_rCCB1offsetFunction, C_OCBOCB0CCB_rCCB1radicandFunction, C_OCBOCB0CCB_rCCB1scalarFunction)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#            'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#           'C_OCBOCB0CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']},
#           'C_OCBOCB0CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#            'parameters': ['L_0', 'L_N1', 'k_0']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_rCCB1radicandFunction',
#           'offset': 'C_OCBOCB0CCB_rCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB0CCB_rCCB1scalarFunction'},
#          'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}}]}}},
#    'constantAmplitudeCalculations': {'C_OCBOCB0CCB_tCCB': [{'C_OCBOCB0CCB_tCCB0radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB0CCB_tCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB0CCB_tCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB0CCB_tCCB0scalar': {'component': -1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#        'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']},
#        'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#        'C_OCBOCB0CCB_tCCB0offsetFunction',
#        'C_OCBOCB0CCB_tCCB0radicandFunction',
#        'C_OCBOCB0CCB_tCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB0inverseCoefficentFunction, C_OCBOCB0CCB_tCCB0offsetFunction, C_OCBOCB0CCB_tCCB0radicandFunction, C_OCBOCB0CCB_tCCB0scalarFunction)>,
#       'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#          'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#         'C_OCBOCB0CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']},
#         'C_OCBOCB0CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB0radicandFunction',
#         'offset': 'C_OCBOCB0CCB_tCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB0CCB_tCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB0CCB_tCCB0scalarFunction'},
#        'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
#      {'C_OCBOCB0CCB_tCCB1radicand': {'component': B_0**2*exp(2*L_0*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_-1*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB0CCB_tCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB0CCB_tCCB1inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB0CCB_tCCB1scalar': {'component': 1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#        'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']},
#        'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#        'C_OCBOCB0CCB_tCCB1offsetFunction',
#        'C_OCBOCB0CCB_tCCB1radicandFunction',
#        'C_OCBOCB0CCB_tCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_tCCB1inverseCoefficentFunction, C_OCBOCB0CCB_tCCB1offsetFunction, C_OCBOCB0CCB_tCCB1radicandFunction, C_OCBOCB0CCB_tCCB1scalarFunction)>,
#       'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#          'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#         'C_OCBOCB0CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']},
#         'C_OCBOCB0CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_tCCB1radicandFunction',
#         'offset': 'C_OCBOCB0CCB_tCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB0CCB_tCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB0CCB_tCCB1scalarFunction'},
#        'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}}],
#     'C_OCBOCB0CCB_rCCB': [{'C_OCBOCB0CCB_rCCB0radicand': {'component': B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB0CCB_rCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB0CCB_rCCB0inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB0CCB_rCCB0scalar': {'component': -exp(k_0*(L_-1 + L_0)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#        'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']},
#        'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']}},
#       'generalFunctionParameters': ['C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#        'C_OCBOCB0CCB_rCCB0offsetFunction',
#        'C_OCBOCB0CCB_rCCB0radicandFunction',
#        'C_OCBOCB0CCB_rCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_rCCB0inverseCoefficentFunction, C_OCBOCB0CCB_rCCB0offsetFunction, C_OCBOCB0CCB_rCCB0radicandFunction, C_OCBOCB0CCB_rCCB0scalarFunction)>,
#       'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#          'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#         'C_OCBOCB0CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']},
#         'C_OCBOCB0CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_rCCB0radicandFunction',
#         'offset': 'C_OCBOCB0CCB_rCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB0CCB_rCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB0CCB_rCCB0scalarFunction'},
#        'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}},
#      {'C_OCBOCB0CCB_rCCB1radicand': {'component': B_0**2*exp(2*L_-1*k_0) - 2*B_0*B_1*exp(k_0*(L_-1 + L_0)) + B_1**2*exp(2*L_0*k_0) - 2*N_0*k_0*exp(2*L_-1*k_0) + 2*N_0*k_0*exp(2*L_0*k_0),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB0CCB_rCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB0CCB_rCCB1inverseCoefficent': {'component': exp(2*L_-1*k_0) - exp(2*L_0*k_0),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB0CCB_rCCB1scalar': {'component': exp(k_0*(L_-1 + L_0)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB0CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#         'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#        'C_OCBOCB0CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']},
#        'C_OCBOCB0CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#         'parameters': ['L_0', 'L_N1', 'k_0']}},
#       'generalFunctionParameters': ['C_OCBOCB0CCB_rCCB1inverseCoefficentFunction',
#        'C_OCBOCB0CCB_rCCB1offsetFunction',
#        'C_OCBOCB0CCB_rCCB1radicandFunction',
#        'C_OCBOCB0CCB_rCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB0CCB_rCCB1inverseCoefficentFunction, C_OCBOCB0CCB_rCCB1offsetFunction, C_OCBOCB0CCB_rCCB1radicandFunction, C_OCBOCB0CCB_rCCB1scalarFunction)>,
#       'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB0CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_0, B_1, L_0, L_N1, N_0, k_0)>,
#          'parameters': ['B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0']},
#         'C_OCBOCB0CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']},
#         'C_OCBOCB0CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_N1, k_0)>,
#          'parameters': ['L_0', 'L_N1', 'k_0']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB0CCB_rCCB1radicandFunction',
#         'offset': 'C_OCBOCB0CCB_rCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB0CCB_rCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB0CCB_rCCB1scalarFunction'},
#        'allParameters': {'B_0', 'B_1', 'L_0', 'L_N1', 'N_0', 'k_0'}}}]}},
#   {'amplitudeCoefficientEquations': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f33eb0e19f0>,
#     'waveEquation': Eq(V_1*psi_1(x) - hbarX**2*Derivative(psi_1(x), (x, 2))/(2*m), E_{total}*psi_1(x)),
#     'normalization': Eq(Integral(psi_1(x)*conjugate(psi_1(x)), (x, L_0, L_1)), N_1),
#     'generalSolution': {'boundries': {psi_1(L_0): B_1, psi_1(L_1): B_2},
#      'harmonicConstantEquation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#      'generalSolution': Eq(psi_1(x), (B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(k_1*x) + (-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(-k_1*x))},
#     'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_1(L_0): B_1,
#        psi_1(L_1): B_2},
#       'harmonicConstantEquation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#       'generalSolution': Eq(psi_1(x), (B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(k_1*x) + (-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(-k_1*x))},
#      'exponential': Eq(psi_1(x), C_{{1}_r}*exp(-k_1*x) + C_{{1}_t}*exp(k_1*x)),
#      'amplitudes': {'transmission': B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#       'reflection': -B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#       'harmonicConstant': k_1},
#      'expandedExponential': C_{{1}_r}*conjugate(C_{{1}_t}) + C_{{1}_r}*exp(-2*k_1*x)*conjugate(C_{{1}_r}) + C_{{1}_t}*exp(2*k_1*x)*conjugate(C_{{1}_t}) + C_{{1}_t}*conjugate(C_{{1}_r})},
#     'constarinedParticularSolutions': {'regionSymbols': <new_attempt.stateless.RegionSymbols at 0x7f33eb0e19f0>,
#      'unconstrainedParticularSolution': {'generalSolution': {'boundries': {psi_1(L_0): B_1,
#         psi_1(L_1): B_2},
#        'harmonicConstantEquation': Eq(k_1, sqrt(2)*sqrt(m)*sqrt(-E_{total} + V_1)/hbarX),
#        'generalSolution': Eq(psi_1(x), (B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(k_1*x) + (-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))*exp(-k_1*x))},
#       'exponential': Eq(psi_1(x), C_{{1}_r}*exp(-k_1*x) + C_{{1}_t}*exp(k_1*x)),
#       'amplitudes': {'transmission': B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#        'reflection': -B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#        'harmonicConstant': k_1},
#       'expandedExponential': C_{{1}_r}*conjugate(C_{{1}_t}) + C_{{1}_r}*exp(-2*k_1*x)*conjugate(C_{{1}_r}) + C_{{1}_t}*exp(2*k_1*x)*conjugate(C_{{1}_t}) + C_{{1}_t}*conjugate(C_{{1}_r})},
#      'intermediateSolutions': {'unconstrainedAmplitudes': {'transmission': [(-2*C_{{1}_r}*L_0*k_1*exp(k_1*(L_0 + L_1)) + 2*C_{{1}_r}*L_1*k_1*exp(k_1*(L_0 + L_1)) - sqrt(4*C_{{1}_r}**2*L_0**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - 8*C_{{1}_r}**2*L_0*L_1*k_1**2*exp(2*k_1*(L_0 + L_1)) + 4*C_{{1}_r}**2*L_1**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - C_{{1}_r}**2*exp(4*L_0*k_1) - C_{{1}_r}**2*exp(4*L_1*k_1) + 2*C_{{1}_r}**2*exp(2*k_1*(L_0 + L_1)) + 2*N_1*k_1*exp(2*k_1*(L_0 + 2*L_1)) - 2*N_1*k_1*exp(2*k_1*(2*L_0 + L_1))))*exp(-k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#         (-2*C_{{1}_r}*L_0*k_1*exp(k_1*(L_0 + L_1)) + 2*C_{{1}_r}*L_1*k_1*exp(k_1*(L_0 + L_1)) + sqrt(4*C_{{1}_r}**2*L_0**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - 8*C_{{1}_r}**2*L_0*L_1*k_1**2*exp(2*k_1*(L_0 + L_1)) + 4*C_{{1}_r}**2*L_1**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - C_{{1}_r}**2*exp(4*L_0*k_1) - C_{{1}_r}**2*exp(4*L_1*k_1) + 2*C_{{1}_r}**2*exp(2*k_1*(L_0 + L_1)) + 2*N_1*k_1*exp(2*k_1*(L_0 + 2*L_1)) - 2*N_1*k_1*exp(2*k_1*(2*L_0 + L_1))))*exp(-k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))],
#        'reflection': [(-2*C_{{1}_t}*L_0*k_1*exp(k_1*(L_0 + L_1)) + 2*C_{{1}_t}*L_1*k_1*exp(k_1*(L_0 + L_1)) - sqrt(4*C_{{1}_t}**2*L_0**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - 8*C_{{1}_t}**2*L_0*L_1*k_1**2*exp(2*k_1*(L_0 + L_1)) + 4*C_{{1}_t}**2*L_1**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - C_{{1}_t}**2*exp(4*L_0*k_1) - C_{{1}_t}**2*exp(4*L_1*k_1) + 2*C_{{1}_t}**2*exp(2*k_1*(L_0 + L_1)) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1)))*exp(k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#         (-2*C_{{1}_t}*L_0*k_1*exp(k_1*(L_0 + L_1)) + 2*C_{{1}_t}*L_1*k_1*exp(k_1*(L_0 + L_1)) + sqrt(4*C_{{1}_t}**2*L_0**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - 8*C_{{1}_t}**2*L_0*L_1*k_1**2*exp(2*k_1*(L_0 + L_1)) + 4*C_{{1}_t}**2*L_1**2*k_1**2*exp(2*k_1*(L_0 + L_1)) - C_{{1}_t}**2*exp(4*L_0*k_1) - C_{{1}_t}**2*exp(4*L_1*k_1) + 2*C_{{1}_t}**2*exp(2*k_1*(L_0 + L_1)) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1)))*exp(k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))]},
#       'intermediateSolutions': {'transmission': Eq((B_1*exp(L_0*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) - B_2*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))**2, (C_{{1}_r}**2*exp(2*L_0*k_1) - C_{{1}_r}**2*exp(2*L_1*k_1) + 2*N_1*k_1*exp(2*k_1*(L_0 + L_1)))*exp(-2*k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))),
#        'reflection': Eq((-B_1*exp(L_0*k_1)*exp(2*L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)) + B_2*exp(2*L_0*k_1)*exp(L_1*k_1)/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))**2, (C_{{1}_t}**2*exp(2*L_0*k_1) - C_{{1}_t}**2*exp(2*L_1*k_1) + 2*N_1*k_1)*exp(2*k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1)))}},
#      'constrainedParticularSolution': {'amplitudeConstrainedSolutions': {'transmission': [-sqrt(B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#         sqrt(B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))],
#        'reflection': [-sqrt(B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1))*exp(k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1)),
#         sqrt(B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1))*exp(k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))]},
#       'amplitudeConstrainedSolution': {'transmission': Eq(C_{{1}_t}**2, (-B_1**2*exp(2*L_1*k_1) + 2*B_1*B_2*exp(k_1*(L_0 + L_1)) - B_2**2*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_1*k_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))**2),
#        'reflection': Eq(C_{{1}_r}**2, (-B_1**2*exp(2*L_0*k_1) + 2*B_1*B_2*exp(k_1*(L_0 + L_1)) - B_2**2*exp(2*L_1*k_1) + 2*N_1*k_1*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_1*k_1))*exp(2*k_1*(L_0 + L_1))/(exp(2*L_0*k_1) - exp(2*L_1*k_1))**2)}}},
#     'extrapolatedComponentsOfConstants': {'C_OCBOCB1CCB_tCCB': {'components': [{'C_OCBOCB1CCB_tCCB0radicand': {'component': B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB1CCB_tCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB1CCB_tCCB0inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB1CCB_tCCB0scalar': {'component': -1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#           'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#          'C_OCBOCB1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_tCCB0inverseCoefficentFunction',
#          'C_OCBOCB1CCB_tCCB0offsetFunction',
#          'C_OCBOCB1CCB_tCCB0radicandFunction',
#          'C_OCBOCB1CCB_tCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_tCCB0inverseCoefficentFunction, C_OCBOCB1CCB_tCCB0offsetFunction, C_OCBOCB1CCB_tCCB0radicandFunction, C_OCBOCB1CCB_tCCB0scalarFunction)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#            'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#           'C_OCBOCB1CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']},
#           'C_OCBOCB1CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_tCCB0radicandFunction',
#           'offset': 'C_OCBOCB1CCB_tCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB1CCB_tCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB1CCB_tCCB0scalarFunction'},
#          'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}},
#        {'C_OCBOCB1CCB_tCCB1radicand': {'component': B_1**2*exp(2*L_1*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_0*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB1CCB_tCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB1CCB_tCCB1inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB1CCB_tCCB1scalar': {'component': 1,
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#           'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#          'C_OCBOCB1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_tCCB1inverseCoefficentFunction',
#          'C_OCBOCB1CCB_tCCB1offsetFunction',
#          'C_OCBOCB1CCB_tCCB1radicandFunction',
#          'C_OCBOCB1CCB_tCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_tCCB1inverseCoefficentFunction, C_OCBOCB1CCB_tCCB1offsetFunction, C_OCBOCB1CCB_tCCB1radicandFunction, C_OCBOCB1CCB_tCCB1scalarFunction)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#            'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#           'C_OCBOCB1CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']},
#           'C_OCBOCB1CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_tCCB1radicandFunction',
#           'offset': 'C_OCBOCB1CCB_tCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB1CCB_tCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB1CCB_tCCB1scalarFunction'},
#          'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}}]},
#      'C_OCBOCB1CCB_rCCB': {'components': [{'C_OCBOCB1CCB_rCCB0radicand': {'component': B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB1CCB_rCCB0offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB1CCB_rCCB0inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB1CCB_rCCB0scalar': {'component': -exp(k_1*(L_0 + L_1)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#           'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCB1CCB_rCCB0offsetFunction',
#          'C_OCBOCB1CCB_rCCB0radicandFunction',
#          'C_OCBOCB1CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB1CCB_rCCB0inverseCoefficentFunction, C_OCBOCB1CCB_rCCB0offsetFunction, C_OCBOCB1CCB_rCCB0radicandFunction, C_OCBOCB1CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB1CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#            'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']},
#           'C_OCBOCB1CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#            'parameters': ['L_0', 'L_1', 'k_1']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB1CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCB1CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB1CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB1CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1'}}},
#        {'C_OCBOCB1CCB_rCCB1radicand': {'component': B_1**2*exp(2*L_0*k_1) - 2*B_1*B_2*exp(k_1*(L_0 + L_1)) + B_2**2*exp(2*L_1*k_1) - 2*N_1*k_1*exp(2*L_0*k_1) + 2*N_1*k_1*exp(2*L_1*k_1),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB1CCB_rCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB1CCB_rCCB1inverseCoefficent': {'component': exp(2*L_0*k_1) - exp(2*L_1*k_1),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB1CCB_rCCB1scalar': {'component': exp(k_1*(L_0 + L_1)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB1CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_1, B_2, L_0, L_1, N_1, k_1)>,
#           'parameters': ['B_1', 'B_2', 'L_0', 'L_1', 'N_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB1CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']},
#          'C_OCBOCB1CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_0, L_1, k_1)>,
#           'parameters': ['L_0', 'L_1', 'k_1']}},
#         'generalFunctionParameters': ['C_OCBOCB1CCB_rCCB1inverseCoefficentFunction',
#          'C_OCBOCB1CCB_rCCB1offsetFunction',
#          'C_OCBOCB1CCB_rCCB1radicandFunction',
#          'C_OCBOCB1CCB_rCCB1scalarFunction'],
# ...
#          'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#           'parameters': ['L_1', 'L_2', 'k_2']},
#          'C_OCBOCB2CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#           'parameters': ['L_1', 'L_2', 'k_2']}},
#         'generalFunctionParameters': ['C_OCBOCB2CCB_rCCB0inverseCoefficentFunction',
#          'C_OCBOCB2CCB_rCCB0offsetFunction',
#          'C_OCBOCB2CCB_rCCB0radicandFunction',
#          'C_OCBOCB2CCB_rCCB0scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_rCCB0inverseCoefficentFunction, C_OCBOCB2CCB_rCCB0offsetFunction, C_OCBOCB2CCB_rCCB0radicandFunction, C_OCBOCB2CCB_rCCB0scalarFunction)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#            'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#           'C_OCBOCB2CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#            'parameters': ['L_1', 'L_2', 'k_2']},
#           'C_OCBOCB2CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#            'parameters': ['L_1', 'L_2', 'k_2']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_rCCB0radicandFunction',
#           'offset': 'C_OCBOCB2CCB_rCCB0offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB2CCB_rCCB0scalarFunction'},
#          'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}},
#        {'C_OCBOCB2CCB_rCCB1radicand': {'component': B_2**2*exp(2*L_1*k_2) - 2*B_2*B_3*exp(k_2*(L_1 + L_2)) + B_3**2*exp(2*L_2*k_2) - 2*N_2*k_2*exp(2*L_1*k_2) + 2*N_2*k_2*exp(2*L_2*k_2),
#          'canonicalName': 'radicand'},
#         'C_OCBOCB2CCB_rCCB1offset': {'component': 0,
#          'canonicalName': 'offset'},
#         'C_OCBOCB2CCB_rCCB1inverseCoefficent': {'component': exp(2*L_1*k_2) - exp(2*L_2*k_2),
#          'canonicalName': 'inverseCoefficent'},
#         'C_OCBOCB2CCB_rCCB1scalar': {'component': exp(k_2*(L_1 + L_2)),
#          'canonicalName': 'scalar'},
#         'componentFunctions': {'C_OCBOCB2CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#           'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#          'C_OCBOCB2CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#           'parameters': []},
#          'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#           'parameters': ['L_1', 'L_2', 'k_2']},
#          'C_OCBOCB2CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#           'parameters': ['L_1', 'L_2', 'k_2']}},
#         'generalFunctionParameters': ['C_OCBOCB2CCB_rCCB1inverseCoefficentFunction',
#          'C_OCBOCB2CCB_rCCB1offsetFunction',
#          'C_OCBOCB2CCB_rCCB1radicandFunction',
#          'C_OCBOCB2CCB_rCCB1scalarFunction'],
#         'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_rCCB1inverseCoefficentFunction, C_OCBOCB2CCB_rCCB1offsetFunction, C_OCBOCB2CCB_rCCB1radicandFunction, C_OCBOCB2CCB_rCCB1scalarFunction)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#         'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#         'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#            'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#           'C_OCBOCB2CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#            'parameters': []},
#           'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#            'parameters': ['L_1', 'L_2', 'k_2']},
#           'C_OCBOCB2CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#            'parameters': ['L_1', 'L_2', 'k_2']}},
#          'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_rCCB1radicandFunction',
#           'offset': 'C_OCBOCB2CCB_rCCB1offsetFunction',
#           'inverseCoefficent': 'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction',
#           'scalar': 'C_OCBOCB2CCB_rCCB1scalarFunction'},
#          'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}}]}}},
#    'constantAmplitudeCalculations': {'C_OCBOCB2CCB_tCCB': [{'C_OCBOCB2CCB_tCCB0radicand': {'component': B_2**2*exp(2*L_2*k_2) - 2*B_2*B_3*exp(k_2*(L_1 + L_2)) + B_3**2*exp(2*L_1*k_2) - 2*N_2*k_2*exp(2*L_1*k_2) + 2*N_2*k_2*exp(2*L_2*k_2),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB2CCB_tCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB2CCB_tCCB0inverseCoefficent': {'component': exp(2*L_1*k_2) - exp(2*L_2*k_2),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB2CCB_tCCB0scalar': {'component': -1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB2CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#        'C_OCBOCB2CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB2CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']},
#        'C_OCBOCB2CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB2CCB_tCCB0inverseCoefficentFunction',
#        'C_OCBOCB2CCB_tCCB0offsetFunction',
#        'C_OCBOCB2CCB_tCCB0radicandFunction',
#        'C_OCBOCB2CCB_tCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_tCCB0inverseCoefficentFunction, C_OCBOCB2CCB_tCCB0offsetFunction, C_OCBOCB2CCB_tCCB0radicandFunction, C_OCBOCB2CCB_tCCB0scalarFunction)>,
#       'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_tCCB0radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#          'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#         'C_OCBOCB2CCB_tCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB2CCB_tCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']},
#         'C_OCBOCB2CCB_tCCB0scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_tCCB0radicandFunction',
#         'offset': 'C_OCBOCB2CCB_tCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB2CCB_tCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB2CCB_tCCB0scalarFunction'},
#        'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}},
#      {'C_OCBOCB2CCB_tCCB1radicand': {'component': B_2**2*exp(2*L_2*k_2) - 2*B_2*B_3*exp(k_2*(L_1 + L_2)) + B_3**2*exp(2*L_1*k_2) - 2*N_2*k_2*exp(2*L_1*k_2) + 2*N_2*k_2*exp(2*L_2*k_2),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB2CCB_tCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB2CCB_tCCB1inverseCoefficent': {'component': exp(2*L_1*k_2) - exp(2*L_2*k_2),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB2CCB_tCCB1scalar': {'component': 1, 'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB2CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#        'C_OCBOCB2CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB2CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']},
#        'C_OCBOCB2CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []}},
#       'generalFunctionParameters': ['C_OCBOCB2CCB_tCCB1inverseCoefficentFunction',
#        'C_OCBOCB2CCB_tCCB1offsetFunction',
#        'C_OCBOCB2CCB_tCCB1radicandFunction',
#        'C_OCBOCB2CCB_tCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_tCCB1inverseCoefficentFunction, C_OCBOCB2CCB_tCCB1offsetFunction, C_OCBOCB2CCB_tCCB1radicandFunction, C_OCBOCB2CCB_tCCB1scalarFunction)>,
#       'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_tCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#          'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#         'C_OCBOCB2CCB_tCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB2CCB_tCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']},
#         'C_OCBOCB2CCB_tCCB1scalarFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_tCCB1radicandFunction',
#         'offset': 'C_OCBOCB2CCB_tCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB2CCB_tCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB2CCB_tCCB1scalarFunction'},
#        'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}}],
#     'C_OCBOCB2CCB_rCCB': [{'C_OCBOCB2CCB_rCCB0radicand': {'component': B_2**2*exp(2*L_1*k_2) - 2*B_2*B_3*exp(k_2*(L_1 + L_2)) + B_3**2*exp(2*L_2*k_2) - 2*N_2*k_2*exp(2*L_1*k_2) + 2*N_2*k_2*exp(2*L_2*k_2),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB2CCB_rCCB0offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB2CCB_rCCB0inverseCoefficent': {'component': exp(2*L_1*k_2) - exp(2*L_2*k_2),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB2CCB_rCCB0scalar': {'component': -exp(k_2*(L_1 + L_2)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB2CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#        'C_OCBOCB2CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']},
#        'C_OCBOCB2CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']}},
#       'generalFunctionParameters': ['C_OCBOCB2CCB_rCCB0inverseCoefficentFunction',
#        'C_OCBOCB2CCB_rCCB0offsetFunction',
#        'C_OCBOCB2CCB_rCCB0radicandFunction',
#        'C_OCBOCB2CCB_rCCB0scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_rCCB0inverseCoefficentFunction, C_OCBOCB2CCB_rCCB0offsetFunction, C_OCBOCB2CCB_rCCB0radicandFunction, C_OCBOCB2CCB_rCCB0scalarFunction)>,
#       'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_rCCB0radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#          'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#         'C_OCBOCB2CCB_rCCB0offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']},
#         'C_OCBOCB2CCB_rCCB0scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_rCCB0radicandFunction',
#         'offset': 'C_OCBOCB2CCB_rCCB0offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB2CCB_rCCB0inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB2CCB_rCCB0scalarFunction'},
#        'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}},
#      {'C_OCBOCB2CCB_rCCB1radicand': {'component': B_2**2*exp(2*L_1*k_2) - 2*B_2*B_3*exp(k_2*(L_1 + L_2)) + B_3**2*exp(2*L_2*k_2) - 2*N_2*k_2*exp(2*L_1*k_2) + 2*N_2*k_2*exp(2*L_2*k_2),
#        'canonicalName': 'radicand'},
#       'C_OCBOCB2CCB_rCCB1offset': {'component': 0, 'canonicalName': 'offset'},
#       'C_OCBOCB2CCB_rCCB1inverseCoefficent': {'component': exp(2*L_1*k_2) - exp(2*L_2*k_2),
#        'canonicalName': 'inverseCoefficent'},
#       'C_OCBOCB2CCB_rCCB1scalar': {'component': exp(k_2*(L_1 + L_2)),
#        'canonicalName': 'scalar'},
#       'componentFunctions': {'C_OCBOCB2CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#         'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#        'C_OCBOCB2CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#         'parameters': []},
#        'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']},
#        'C_OCBOCB2CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#         'parameters': ['L_1', 'L_2', 'k_2']}},
#       'generalFunctionParameters': ['C_OCBOCB2CCB_rCCB1inverseCoefficentFunction',
#        'C_OCBOCB2CCB_rCCB1offsetFunction',
#        'C_OCBOCB2CCB_rCCB1radicandFunction',
#        'C_OCBOCB2CCB_rCCB1scalarFunction'],
#       'generalFunction': <function _lambdifygenerated(C_OCBOCB2CCB_rCCB1inverseCoefficentFunction, C_OCBOCB2CCB_rCCB1offsetFunction, C_OCBOCB2CCB_rCCB1radicandFunction, C_OCBOCB2CCB_rCCB1scalarFunction)>,
#       'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'],
#       'function': <function new_attempt.stateless.generateNumericalFunctionFromGeneralFunctionAndComponents.<locals>.calculate(**kwargs)>,
#       'numericalSolutionComponents': {'componentFunctions': {'C_OCBOCB2CCB_rCCB1radicandFunction': {'function': <function _lambdifygenerated(B_2, B_3, L_1, L_2, N_2, k_2)>,
#          'parameters': ['B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2']},
#         'C_OCBOCB2CCB_rCCB1offsetFunction': {'function': <function _lambdifygenerated()>,
#          'parameters': []},
#         'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']},
#         'C_OCBOCB2CCB_rCCB1scalarFunction': {'function': <function _lambdifygenerated(L_1, L_2, k_2)>,
#          'parameters': ['L_1', 'L_2', 'k_2']}},
#        'canoticalParameters': {'radicand': 'C_OCBOCB2CCB_rCCB1radicandFunction',
#         'offset': 'C_OCBOCB2CCB_rCCB1offsetFunction',
#         'inverseCoefficent': 'C_OCBOCB2CCB_rCCB1inverseCoefficentFunction',
#         'scalar': 'C_OCBOCB2CCB_rCCB1scalarFunction'},
#        'allParameters': {'B_2', 'B_3', 'L_1', 'L_2', 'N_2', 'k_2'}}}]}}]}

# %%
testBasicParameters = {
    "V_0" : 1, 
    "V_1" : 1, 
    "V_2" : 1, 
    "L_0" : 1, 
    "L_1" : 1, 
    "L_2" : 2, 
    "N_0" : .1, 
    "N_1" : .2, 
    "N_2" : .7, 
    "m" : 1, 
    "E_OCBtotalCCB" : 4, 
    "E_total" : 4, 
    "hbarX" : 1, 
}

# %%
constants = computeSimulationConstants(preliminaryData, regionFunctions, testBasicParameters, 1, 1)
# Out:
# <lambdifygenerated-1>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2)*sqrt(m)*sqrt(-E_OCBtotalCCB + V_0)/hbarX
# <lambdifygenerated-2>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2)*sqrt(m)*sqrt(-E_OCBtotalCCB + V_1)/hbarX
# <lambdifygenerated-3>:2: RuntimeWarning: invalid value encountered in sqrt
#   return sqrt(2)*sqrt(m)*sqrt(-E_OCBtotalCCB + V_2)/hbarX
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 constants = computeSimulationConstants(preliminaryData, regionFunctions, testBasicParameters, 1, 1)
#
# File ~/work/numerical_py/new_attempt/stateless.py:962, in computeSimulationConstants(preliminaryData, regionFunctions, basicArguments, initialTransmission, initialReflection)
#     947 def computeSimulationConstants(
#     948             preliminaryData : dict,
#     949             regionFunctions : dict,
#    (...)
#     952             initialReflection : float,
#     953         ) -> dict:
#     954     harmonicConstants = {
#     955             symbolicToIdentifier(functionData["equation"].lhs)
#     956                     : computeHarmonicConstant(
#    (...)
#     960             for functionData in regionFunctions["harmonicConstantFunctions"]
#     961         }
# --> 962     transfers = computeTransferConstantsFromHarmonicConsants(
#     963             regionFunctions,
#     964             basicArguments | harmonicConstants,
#     965             initialTransmission,
#     966             initialReflection
#     967         )
#     968     boundryIndexedTransfers = replaceKeys(
#     969             preliminaryData["regionSymbols"],
#     970             transfers
#     971         )
#     972     amplitudeConstants = computeAmplitudeConstants(
#     973             regionFunctions,
#     974             basicArguments | boundryIndexedTransfers | harmonicConstants
#     975         )
#
# File ~/work/numerical_py/new_attempt/stateless.py:925, in computeTransferConstantsFromHarmonicConsants(regionFunctions, initialTransmission, initialReflection, transmissionReflectionCoefficientArguments)
#     923 transmissionReflectionCoefficients = list(reversed(transmissionReflectionCoefficients))
#     924 transfers = list(reversed(regionFunctions["transferFunctions"]["transfers"]))
# --> 925 return performTransfers(
#     926         transfers,
#     927         initialTransmission,
#     928         initialReflection,
#     929         transmissionReflectionCoefficients
#     930     )
#
# File ~/work/numerical_py/new_attempt/stateless.py:286, in performTransfers(transfers, initialTransmission, initialReflection, transmissionReflectionCoefficients)
#     280 def performTransfers(
#     281             transfers : list[dict],
#     282             initialTransmission,
#     283             initialReflection,
#     284             transmissionReflectionCoefficients : dict
#     285         ) -> dict:
# --> 286     functions = transfers[0]['functionData']['functions']
#     287     inputs = transfers[0]['matricies']['inputs']
#     288     satisfiedArguments, waveFunctionInputs = inputCoefficients(
#     289             functions,
#     290             inputs,
#     291             transmissionReflectionCoefficients[0]
#     292         )
#
# IndexError: list index out of range

# %%
constants
